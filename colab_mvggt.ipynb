# %%
# !git clone https://github.com/Enot3811/mvggt.git
# %cd mvggt

# %%
# !pip install -r requirements_demo_colab.txt

# %%
# !mkdir -p ckpts
# !hf download yyfz233/Pi3 --local-dir ckpts/Pi3
# !hf download FacebookAI/roberta-base --local-dir ckpts/roberta-base
# !hf download sosppxo/mvggt --local-dir ckpts/mvggt

# %%
# !python demo_gradio.py
